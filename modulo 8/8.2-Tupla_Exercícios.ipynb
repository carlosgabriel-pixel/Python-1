# %% [markdown]
# # Tupla
#
# ## Aula 8.2

# %% [markdown]
# ### Q1.
#
# Escreva uma função ```calcula_area_perimetro``` que recebe **apenas um parâmetro** ```dimensoes``` e calcula a área e o perímetro a partir das dimensões dadas.
# - ```dimensoes``` é uma tupla (largura, comprimento) com as dimensões de um terreno retangular
# - Sua função deve calcular e retornar as seguintes operações
#    - $area = largura \times comprimento$
#    - $perimetro = 2\times(largura + comprimento)$

# %%
# Implemente aqui a função calcula_area_perimetro
def calcula_area_perimetro(dimensoes):
    # Desempacota a tupla recebida em duas variáveis
    largura, comprimento = dimensoes
    
    # Realiza os cálculos solicitados
    area = largura * comprimento
    perimetro = 2 * (largura + comprimento)
    
    # Retorna os dois valores calculados (gerando uma nova tupla de retorno)
    return area, perimetro

# Exemplo de uso baseado no enunciado
largura = 5
comprimento = 7

# Monta a tupla para passar como o parâmetro único exigido
dimensoes_terreno = (largura, comprimento)
retorno = calcula_area_perimetro(dimensoes_terreno)

print(f"Retorno: {retorno}, Tipo: {type(retorno)}")
# Saída esperada: Retorno: (35, 24), Tipo: <class 'tuple'>

# %%
# Complete o exemplo de uso abaixo
largura = 5
comprimento = 7

retorno = ## complete aqui a chamada da função
print(retorno, type(retorno))

# %% [markdown]
# ### Q2.
#
# Dada uma string, imprima todas as vogais que aparecem na string, bem como todos os índices onde elas ocorrem. Para isso, use a função ```enumerate```.

# %%
frase = "O rato roeu a roupa da Alice"

# Implemente aqui sua solução
frase = "O rato roeu a roupa da Alice"
vogais = "aeiouAEIOU"

print("Vogais encontradas e seus respectivos índices:")
for idx, caractere in enumerate(frase):
    if caractere in vogais:
        print(f"Índice {idx}: '{caractere}'")

# %% [markdown]
# ### Q3.
#
# Escreva uma função em Python chamada ```ordenar_tuplas``` que recebe uma lista de tuplas, cada uma contendo o nome de um aluno e sua respectiva média, e retorna uma nova lista ordenada em ordem decrescente de médias.

# %%
# Implemente aqui a função ordenar_tuplas
def ordenar_tuplas(lista_alunos):
    # O lambda indica que a ordenação deve olhar para o elemento na posição 1 (a média)
    # reverse=True garante a ordem decrescente (maior nota para a menor)
    return sorted(lista_alunos, key=lambda aluno: aluno[1], reverse=True)

# Exemplo de uso fornecido no enunciado
alunos_notas = [('Alice', 8.5), ('Bob', 7.2), ('Charlie', 9.0), ('David', 8.8)]
resultado = ordenar_tuplas(alunos_notas)

print(resultado)
# Saída esperada: [('Charlie', 9.0), ('David', 8.8), ('Alice', 8.5), ('Bob', 7.2)]

# %%
# Exemplo de uso:
alunos_notas = [('Alice', 8.5), ('Bob', 7.2), ('Charlie', 9.0), ('David', 8.8)]
resultado = ordenar_tuplas(alunos_notas)
print(resultado)
# Saída esperada: [('Charlie', 9.0), ('David', 8.8), ('Alice', 8.5), ('Bob', 7.2)]

# %% [markdown]
# ### Q4.
#
# Escreva uma função em Python chamada ```comprimir_tuplas``` que recebe uma lista de tuplas, cada uma contendo uma palavra e um número, e retorna uma nova lista de tuplas onde palavras idênticas são agrupadas e seus números são somados.

# %%
# Implemente aqui a função comprimir_tuplas
def comprimir_tuplas(lista_originais):
    acumulador = {}
    
    for palavra, quantidade in lista_originais:
        # Garante a padronização mantendo chaves idênticas juntas se necessário
        # Se a palavra já existe no dicionário, soma a quantidade, senão inicializa com 0
        acumulador[palavra] = acumulador.get(palavra, 0) + quantidade
        
    # Converte o dicionário final de volta para uma lista de tuplas
    return list(acumulador.items())

# Exemplo de uso fornecido no enunciado
tuplas_originais = [('maçã', 3), ('banana', 2), ('maçã', 5), ('laranja', 1), ('banana', 3)]
resultado = comprimir_tuplas(tuplas_originais)

print(resultado)
# Saída esperada: [('maçã', 8), ('banana', 5), ('laranja', 1)]

# %%
# Exemplo de uso:
tuplas_originais = [('maçã', 3), ('banana', 2), ('maçã', 5), ('laranja', 1), ('banana', 3)]
resultado = comprimir_tuplas(tuplas_originais)
print(resultado)
# Saída esperada: [('maçã', 8), ('banana', 5), ('laranja', 1)]

# %% [markdown]
# ### Q5.
#
# - Escreva um script que peça o nome e a idade de todos na fila de uma balada. Crie uma lista de tuplas com os pares ```(nome, idade)``` de cada um.
# - Em seguida crie e imprima duas tuplas apenas com os nomes, uma com os menores de idade que não poderão entrar, e uma com os maiores de idade (```idade >= 18```).

# %%
## Implemente aqui sua solução
fila_balada = []

print("--- Cadastro da Fila da Balada (Digite 'sair' no nome para finalizar) ---")
while True:
    nome = input("Digite o nome: ").strip()
    if nome.lower() == 'sair':
        break
    try:
        idade = int(input(f"Digite a idade de {nome}: "))
        fila_balada.append((nome, idade))
    except ValueError:
        print("Idade inválida! Digite um número inteiro.")

# Filtros e separação extraindo apenas os nomes (elemento [0] da tupla)
maiores_18 = tuple(pessoa[0] for pessoa in fila_balada if pessoa[1] >= 18)
menores_18 = tuple(pessoa[0] for pessoa in fila_balada if pessoa[1] < 18)

print("\n--- Resultados Finais ---")
print(f"Lista de nomes autorizados a entrar (Maioridade >= 18): {maiores_18}")
print(f"Lista de nomes barrados na entrada (Menores de 18): {menores_18}")
